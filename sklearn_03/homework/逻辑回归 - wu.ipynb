# %%
from sklearn import datasets
from sklearn.linear_model.logistic import LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %%
digits = datasets.load_digits()
n_samples = len(digits.images)
X = digits.images.reshape((n_samples, -1))
y = digits.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

# %%
tuned_parameters = [{
    'penalty': ['l1','l2'],
    'C': [0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50, 100],
    'solver': ['liblinear'],
    'multi_class': ['ovr']},
    { 'penalty': ['l2'],
    'C': [0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50, 100],
    'solver': ['lbfgs'],
    'multi_class': ['ovr','multinomial']}]

scores = [ 'precision', 'recall']

# %%
for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()
    clf = GridSearchCV(LogisticRegression(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()

    y_true, y_pred = y_test, clf.predict(X_test)
    
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'C': 0.05, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
#
# Grid scores on development set:
#
# 0.915 (+/-0.025) for {'C': 0.01, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.962 (+/-0.031) for {'C': 0.01, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.955 (+/-0.028) for {'C': 0.05, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.965 (+/-0.015) for {'C': 0.05, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.964 (+/-0.027) for {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.962 (+/-0.015) for {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.958 (+/-0.016) for {'C': 0.5, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.957 (+/-0.017) for {'C': 0.5, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.952 (+/-0.008) for {'C': 1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.956 (+/-0.016) for {'C': 1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.942 (+/-0.015) for {'C': 5, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.950 (+/-0.009) for {'C': 5, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.937 (+/-0.025) for {'C': 10, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.948 (+/-0.011) for {'C': 10, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.936 (+/-0.024) for {'C': 50, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.937 (+/-0.010) for {'C': 50, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.930 (+/-0.033) for {'C': 100, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.935 (+/-0.008) for {'C': 100, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.966 (+/-0.037) for {'C': 0.01, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.970 (+/-0.030) for {'C': 0.01, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.972 (+/-0.025) for {'C': 0.05, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.968 (+/-0.017) for {'C': 0.05, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.970 (+/-0.025) for {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.967 (+/-0.018) for {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.961 (+/-0.019) for {'C': 0.5, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.967 (+/-0.013) for {'C': 0.5, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.954 (+/-0.008) for {'C': 1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.966 (+/-0.012) for {'C': 1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.950 (+/-0.009) for {'C': 5, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.965 (+/-0.012) for {'C': 5, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.946 (+/-0.011) for {'C': 10, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.963 (+/-0.008) for {'C': 10, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.936 (+/-0.025) for {'C': 50, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.962 (+/-0.014) for {'C': 50, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.933 (+/-0.033) for {'C': 100, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.958 (+/-0.020) for {'C': 100, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        89
#           1       0.96      0.96      0.96        90
#           2       0.99      1.00      0.99        92
#           3       0.95      0.95      0.95        93
#           4       0.96      0.99      0.97        76
#           5       0.93      0.96      0.95       108
#           6       0.97      0.98      0.97        89
#           7       0.99      0.97      0.98        78
#           8       0.91      0.84      0.87        92
#           9       0.92      0.92      0.92        92
#
# avg / total       0.96      0.96      0.96       899
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'C': 0.05, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
#
# Grid scores on development set:
#
# 0.911 (+/-0.027) for {'C': 0.01, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.960 (+/-0.029) for {'C': 0.01, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.953 (+/-0.028) for {'C': 0.05, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.963 (+/-0.013) for {'C': 0.05, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.962 (+/-0.025) for {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.959 (+/-0.013) for {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.956 (+/-0.008) for {'C': 0.5, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.953 (+/-0.019) for {'C': 0.5, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.948 (+/-0.015) for {'C': 1, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.952 (+/-0.019) for {'C': 1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.936 (+/-0.021) for {'C': 5, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.945 (+/-0.013) for {'C': 5, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.931 (+/-0.028) for {'C': 10, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.943 (+/-0.015) for {'C': 10, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.933 (+/-0.027) for {'C': 50, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.932 (+/-0.011) for {'C': 50, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.926 (+/-0.040) for {'C': 100, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'liblinear'}
# 0.930 (+/-0.009) for {'C': 100, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'liblinear'}
# 0.965 (+/-0.035) for {'C': 0.01, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.969 (+/-0.030) for {'C': 0.01, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.971 (+/-0.024) for {'C': 0.05, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.966 (+/-0.016) for {'C': 0.05, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.969 (+/-0.024) for {'C': 0.1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.964 (+/-0.017) for {'C': 0.1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.958 (+/-0.020) for {'C': 0.5, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.963 (+/-0.011) for {'C': 0.5, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.950 (+/-0.009) for {'C': 1, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.962 (+/-0.011) for {'C': 1, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.946 (+/-0.013) for {'C': 5, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.961 (+/-0.011) for {'C': 5, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.942 (+/-0.016) for {'C': 10, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.959 (+/-0.009) for {'C': 10, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.932 (+/-0.026) for {'C': 50, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.958 (+/-0.017) for {'C': 50, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.927 (+/-0.034) for {'C': 100, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.954 (+/-0.021) for {'C': 100, 'multi_class': 'multinomial', 'penalty': 'l2', 'solver': 'lbfgs'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        89
#           1       0.96      0.96      0.96        90
#           2       0.99      1.00      0.99        92
#           3       0.95      0.95      0.95        93
#           4       0.96      0.99      0.97        76
#           5       0.93      0.96      0.95       108
#           6       0.97      0.98      0.97        89
#           7       0.99      0.97      0.98        78
#           8       0.91      0.84      0.87        92
#           9       0.92      0.92      0.92        92
#
# avg / total       0.96      0.96      0.96       899
